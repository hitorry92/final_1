# %%
# %pip install autoviz

# %%
# %pip install -U pandas-profiling

# %%
import pandas as pd

# %%
df1 = pd.read_csv("./train.csv")
df2 = pd.read_excel("./Data_Description.xlsx")
# Out:
# C:\Users\SEUNGIN\AppData\Local\Temp\ipykernel_36348\2218443250.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("./train.csv")

# %%
df2
# Out:
#                          컬럼명  \
# 0                         ID
# 1                Customer_ID
# 2                      Month
# 3                       Name
# 4                        Age
# 5                        SSN
# 6                 Occupation
# 7              Annual_Income
# 8      Monthly_Inhand_Salary
# 9          Num_Bank_Accounts
# 10           Num_Credit_Card
# 11             Interest_Rate
# 12               Num_of_Loan
# 13              Type_of_Loan
# 14       Delay_from_due_date
# 15    Num_of_Delayed_Payment
# 16      Changed_Credit_Limit
# 17      Num_Credit_Inquiries
# 18                Credit_Mix
# 19          Outstanding_Debt
# 20  Credit_Utilization_Ratio
# 21        Credit_History_Age
# 22     Payment_of_Min_Amount
# 23       Total_EMI_per_month
# 24   Amount_invested_monthly
# 25         Payment_Behaviour
# 26           Monthly_Balance
# 27              Credit_Score
#
#                                                    설명  \
# ...

# %%
# # profiling
# import ydata_profiling
# pr = df.profile_report() # 프로파일링 결과 리포트를 pr에 저장
# pr.to_file('./df_report.html') # pr_report.html 파일로 저장

# %%
# 컬럼별 고유 식별(데이터적으로 의미 없다.)
df1["ID"]
# Out:
# 0         0x1602
# 1         0x1603
# 2         0x1604
# 3         0x1605
# 4         0x1606
#           ...
# 99995    0x25fe9
# 99996    0x25fea
# 99997    0x25feb
# 99998    0x25fec
# 99999    0x25fed
# Name: ID, Length: 100000, dtype: object

# %%
df1["Customer_ID"]
# Out:
# 0         CUS_0xd40
# 1         CUS_0xd40
# 2         CUS_0xd40
# 3         CUS_0xd40
# 4         CUS_0xd40
#             ...
# 99995    CUS_0x942c
# 99996    CUS_0x942c
# 99997    CUS_0x942c
# 99998    CUS_0x942c
# 99999    CUS_0x942c
# Name: Customer_ID, Length: 100000, dtype: object

# %%
df1["Customer_ID"].unique()
# Out:
# array(['CUS_0xd40', 'CUS_0x21b1', 'CUS_0x2dbc', ..., 'CUS_0xaf61',
#        'CUS_0x8600', 'CUS_0x942c'], dtype=object)

# %%
df1["Customer_ID"].value_counts()
# Out:
# Customer_ID
# CUS_0xd40     8
# CUS_0x9bf4    8
# CUS_0x5ae3    8
# CUS_0xbe9a    8
# CUS_0x4874    8
#              ..
# CUS_0x2eb4    8
# CUS_0x7863    8
# CUS_0x9d89    8
# CUS_0xc045    8
# CUS_0x942c    8
# Name: count, Length: 12500, dtype: int64

# %%
df1["Customer_ID"].value_counts().unique()
# Out:
# array([8], dtype=int64)

# %%
df1.drop_duplicates(subset = "Customer_ID")
# Out:
#             ID Customer_ID    Month             Name  Age          SSN  \
# 0       0x1602   CUS_0xd40  January    Aaron Maashoh   23  821-00-0265
# 8       0x160e  CUS_0x21b1  January  Rick Rothackerj  28_  004-07-5839
# 16      0x161a  CUS_0x2dbc  January           Langep   34  486-85-3974
# 24      0x1626  CUS_0xb891  January           Jasond   54  072-31-6145
# 32      0x1632  CUS_0x1cdb  January           Deepaa   21  615-06-7821
# ...        ...         ...      ...              ...  ...          ...
# 99960  0x25fb6  CUS_0x372c  January  Lucia Mutikanik   18  340-85-7301
# 99968  0x25fc2   CUS_0xf16  January   Maria Sheahanb   44    #F%$D@*&8
# 99976  0x25fce  CUS_0xaf61  January   Chris Wickhamm   49  133-16-7738
# 99984  0x25fda  CUS_0x8600  January   Sarah McBridec   28  031-35-0942
# 99992  0x25fe6  CUS_0x942c  January            Nicks   24  078-73-5990
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df1["SSN"]
# Out:
# 0        821-00-0265
# 1        821-00-0265
# 2        821-00-0265
# 3        821-00-0265
# 4        821-00-0265
#             ...
# 99995    078-73-5990
# 99996    078-73-5990
# 99997    078-73-5990
# 99998    078-73-5990
# 99999    078-73-5990
# Name: SSN, Length: 100000, dtype: object

# %%
df1.drop_duplicates(subset = "SSN")
# Out:
#             ID Customer_ID     Month             Name  Age          SSN  \
# 0       0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265
# 7       0x1609   CUS_0xd40    August              NaN   23    #F%$D@*&8
# 8       0x160e  CUS_0x21b1   January  Rick Rothackerj  28_  004-07-5839
# 16      0x161a  CUS_0x2dbc   January           Langep   34  486-85-3974
# 24      0x1626  CUS_0xb891   January           Jasond   54  072-31-6145
# ...        ...         ...       ...              ...  ...          ...
# 99960  0x25fb6  CUS_0x372c   January  Lucia Mutikanik   18  340-85-7301
# 99969  0x25fc3   CUS_0xf16  February              NaN   45  868-70-2218
# 99976  0x25fce  CUS_0xaf61   January   Chris Wickhamm   49  133-16-7738
# 99984  0x25fda  CUS_0x8600   January   Sarah McBridec   28  031-35-0942
# 99992  0x25fe6  CUS_0x942c   January            Nicks   24  078-73-5990
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df1["SSN"].value_counts()
# Out:
# SSN
# #F%$D@*&8      5572
# 078-73-5990       8
# 486-78-3816       8
# 750-67-7525       8
# 903-50-0305       8
#                ...
# 856-06-6147       4
# 753-72-2651       4
# 331-28-1921       4
# 604-62-6133       4
# 286-44-9634       4
# Name: count, Length: 12501, dtype: int64

# %%
df1[df1["SSN"] =="#F%$D@*&8"]
# Out:
#             ID Customer_ID    Month              Name  Age        SSN  \
# 7       0x1609   CUS_0xd40   August               NaN   23  #F%$D@*&8
# 29      0x162b  CUS_0xb891     June            Jasond   55  #F%$D@*&8
# 51      0x164d  CUS_0x284a    April            Nadiaq   34  #F%$D@*&8
# 54      0x1650  CUS_0x284a     July            Nadiaq  34_  #F%$D@*&8
# 98      0x1694  CUS_0x3e45    March   Harriet McLeodd   35  #F%$D@*&8
# ...        ...         ...      ...               ...  ...        ...
# 99914  0x25f70  CUS_0x1619    March       Phil Wahbao   54  #F%$D@*&8
# 99942  0x25f98  CUS_0xad4f     July  Sabina Zawadzkig  48_  #F%$D@*&8
# 99946  0x25fa0  CUS_0x51b3    March             Ryana   33  #F%$D@*&8
# 99968  0x25fc2   CUS_0xf16  January    Maria Sheahanb   44  #F%$D@*&8
# 99988  0x25fde  CUS_0x8600      May    Sarah McBridec   28  #F%$D@*&8
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...
